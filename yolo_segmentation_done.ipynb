# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 23.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n-seg.pt") # newer version for better sigmentation

result = model("/content/dog_seg_in.jpg")

plt.imshow(result[0].plot())
plt.show()
# Out:
# image 1/1 /content/dog_seg_in.jpg: 640x448 1 dog, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 448)
